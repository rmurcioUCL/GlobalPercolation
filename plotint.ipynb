# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('citiesIntersectionData.csv')

# %%
df.columns
# Out:
# Index(['1.0', '11673', '27603', '8745', '3864890.623000015', '80.64737701',
#        '512853.6667', '157.2522188'],
#       dtype='object')

# %%
sns.lmplot(data=df,x='8745',y='512853.6667')
